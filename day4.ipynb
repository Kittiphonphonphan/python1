# %% [markdown]
# ### Day 4

# %% [markdown]
# 30 Celcius--> 86 Farenheit

# %%
Celcius = int(input())
Farenheit = (Celcius * 9/5) + 32
print(Farenheit)

# %% [markdown]
# ### Math function

# %%
print(abs(-12))
# Out:
# 12

# %%
min(23, 5, -2, 0)
# Out:
# -2

# %%
round(2.45)
round(2.6), int(2.6)
# Out:
# (3, 2)

# %%
round(4.455, 2)
# Out:
# 4.46

# %%
round(-1.235, 3)
# Out:
# -1.235

# %% [markdown]
# ### Conditionals

# %% [markdown]
# if CONDITION:
#     DO_SOMETHING

# %%
if 5 != 4 and 6 > 3:
    if 5 < 4:
        print("NOOOOOOOOOO")
    print("YESSSSSSSS")
print("WOW")
# Out:
# YESSSSSSSS
# WOW

# %% [markdown]
# ### Else

# %%
if 4 > 5:
    print("A")
else:
    print("B")
# Out:
# B

# %% [markdown]
# ### Elif

# %%
if 2 < 3:
    print("O")
elif 3 > 4:
    print("B")
elif 4 > 1:
    print("C")
else:
    print("T")

if 4 > 1:
    print('LOL')
# Out:
# O
# LOL

# %%
money = input()
age = input()

if money > 3000:
    print('Michellin star restaurant!')
    if age >= 20:
        print('CP!')

elif money > 700:
    print('Harbour Paradise Buffet')
    if age >= 20:
        print ('Wine')

elif money > 300:
    print('Teeyai Buffet')
    if age >= 20:
        print('Beer!')

else:
    print('Go back home and eat instant noodle!')
    print('Drink Water please.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 money = input()
#       2 age = input()
# ----> 3 if money > 3000:
#       4     print('Michellin star restaurant!')
#       5     if age >= 20:
#
# TypeError: '>' not supported between instances of 'str' and 'int'
