# %%
print ("Hello world")
# Out:
# Hello world

# %%
print(type(-0))
print(isinstance(-0,str))
# Out:
# <class 'int'>
# False

# %% [markdown]
# Day3

# %%
# int()
a = int(4.0)
a = int("4")
a = int(float("4.0"))
a = int (True)
a = int (False)
print(a)
# Out:
# 0

# %%
# float()
a = float(-2.5)
a = float("-2.5")
a = float(True)
a = float(False)
# a = float("2")
print(a)
# Out:
# 0.0

# %%
# bool()
a = bool(3)
a = bool(-1)
a = bool(0)
a = bool(3)
a = bool(-2)
a = bool(0.000000000000000000000000000000000000000000000000)
a = bool(None)
a = bool("")
print(a)
# Out:
# False

# %%
a = bool(str(float(-2)))

# %%
a = 5
a = True
# dynamic - type programming language

# %% [markdown]
# <!-- Mathematical Operation -->

# %%
a = 3 + 5
a = sum((2 , 6 , 10, 4))

b = 7 + 3
c = 3 + 8
d = 5 * 9

h = 2 ** 0.5
i = 8 ** (1/8)

j = 7 % 4
j = 32 % 5.0
j = 32.0 % 5.0
j = 32.0 % 5.1 # edge cases
j = 32.0 % -5.1
j = -12.5 % -1.15
j = -12.5 % 1
j = -12.5 % True
j = -12.5 % 0
j = -12.5
print (j)
# Out:
# 0.5

# %%
7/3
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
a = 0**0
print(a)
# Out:
# 1

# %%
0 ** 5
0 ** 0
# Out:
# 1

# %% [markdown]
# Order of operations

# %%
a = 2 * 2 - 2 / 2 - 2 % 2 / 2 ** 2
a = (2 * 2) - (2 / 2) - (2 ** 2) # 1 st way
a = 2*2 - 2/2 - 2**2 # 2nd way
print (a)
# Out:
# -1.0

# %% [markdown]
# Variable Adjustmets

# %%
a = 4 + 4
b = 3 * 2
a = a + 1
a = a // 2

a = b / a
print (a)
# Out:
# 1.5

# %% [markdown]
# Short hand

# %%
a = a + 1
a += 1

a = a - 5
a -= 5

a = a * 3
a *= 3

a = a / 5
a /= 5

a = a // 2
a //= 2

a = a ** 2
a **= 2

# %%
a = 5

a = a % 3
a %= 3
print(a)
# Out:
# 2

# %% [markdown]
# Logical Operation

# %% [markdown]
# Proposition (n.): staement that you can assign boolean value to it.
#
# "you are male." is a proposition
#
# "Are you male?/Don't eat in the classroom" is not a proposition

# %%
a = 5

2 > 3 # false
a < 7 # true
2 >= 3 # false
2 <= 3 #true
2 == 4 # false
2 != 4 # true
# Out:
# True

# %%
print(4 > 3 > 3 > 1)
print((4 > 3) and (3 > 3) and (3 > 1))
# Out:
# False
# False

# %%
# not, and, or
print(not True)
print((not 1) > 2)
# Out:
# False
# False

# %%
a = 5
b = 6
print(a != b-1 or b**2 > a)
# Out:
# True

# %%
True or 0
True and 0
0 or 0
0 or 1
True and 5
# Out:
# 5

# %%
5 and True
5 or True
True or 5
# Out:
# True

# %%
# will stop at the first true or the last
print (True or 0)
print (0 or 0)
print
